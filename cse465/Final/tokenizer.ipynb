# %%
corpus = [
    "This is the CSE 465 Course.",
    "This chapter is about tokenization.",
    "This section shows several tokenizer algorithms.",
    "Hopefully, you will be able to understand how they are trained and generate tokens.",
]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
from collections import defaultdict

word_freqs = defaultdict(int)
for text in corpus:
    words_with_offsets = tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str(text)
    new_words = [word for word, offset in words_with_offsets]
    for word in new_words:
        word_freqs[word] += 1

word_freqs
# Out:
# defaultdict(int,
#             {'This': 3,
#              'is': 2,
#              'the': 1,
#              'CSE': 1,
#              '465': 1,
#              'Course': 1,
#              '.': 4,
#              'chapter': 1,
#              'about': 1,
#              'tokenization': 1,
#              'section': 1,
#              'shows': 1,
#              'several': 1,
#              'tokenizer': 1,
#              'algorithms': 1,
#              'Hopefully': 1,
#              ',': 1,
#              'you': 1,
#              'will': 1,
#              'be': 1,
#              'able': 1,
#              'to': 1,
#              'understand': 1,
#              'how': 1,
#              'they': 1,
#              'are': 1,
#              'trained': 1,
#              'and': 1,
#              'generate': 1,
#              'tokens': 1})

# %%
for word in word_freqs.keys():
  print(word[1:])
# Out:
# his
# s
# he
# SE
# 65
# ourse
#
# hapter
# bout
# okenization
# ection
# hows
# everal
# okenizer
# lgorithms
# opefully
#
# ou
# ill
# e
# ble
# o
# nderstand
# ow
# hey
# re
# rained
# nd
# enerate
# okens

# %%
alphabet = []
for word in word_freqs.keys():
    if word[0] not in alphabet:
        alphabet.append(word[0])
    for letter in word[1:]:
        if f"##{letter}" not in alphabet:
            alphabet.append(f"##{letter}")

#alphabet.sort()
alphabet

print(alphabet)
# Out:
# ['T', '##h', '##i', '##s', 'i', 't', '##e', 'C', '##S', '##E', '4', '##6', '##5', '##o', '##u', '##r', '.', 'c', '##a', '##p', '##t', 'a', '##b', '##k', '##n', '##z', 's', '##c', '##w', '##v', '##l', '##g', '##m', 'H', '##f', '##y', ',', 'y', 'w', 'b', 'u', '##d', 'h', 'g']

# %%
vocab = ["[PAD]", "[UNK]", "[CLS]", "[SEP]", "[MASK]"] + alphabet.copy()

# %%
splits = {
    word: [c if i == 0 else f"##{c}" for i, c in enumerate(word)]
    for word in word_freqs.keys()
}
splits
# Out:
# {'This': ['T', '##h', '##i', '##s'],
#  'is': ['i', '##s'],
#  'the': ['t', '##h', '##e'],
#  'CSE': ['C', '##S', '##E'],
#  '465': ['4', '##6', '##5'],
#  'Course': ['C', '##o', '##u', '##r', '##s', '##e'],
#  '.': ['.'],
#  'chapter': ['c', '##h', '##a', '##p', '##t', '##e', '##r'],
#  'about': ['a', '##b', '##o', '##u', '##t'],
#  'tokenization': ['t',
#   '##o',
#   '##k',
#   '##e',
#   '##n',
#   '##i',
#   '##z',
#   '##a',
#   '##t',
#   '##i',
#   '##o',
#   '##n'],
#  'section': ['s', '##e', '##c', '##t', '##i', '##o', '##n'],
#  'shows': ['s', '##h', '##o', '##w', '##s'],
#  'several': ['s', '##e', '##v', '##e', '##r', '##a', '##l'],
#  'tokenizer': ['t', '##o', '##k', '##e', '##n', '##i', '##z', '##e', '##r'],
#  'algorithms': ['a',
#   '##l',
#   '##g',
#   '##o',
#   '##r',
#   '##i',
#   '##t',
#   '##h',
#   '##m',
#   '##s'],
#  'Hopefully': ['H', '##o', '##p', '##e', '##f', '##u', '##l', '##l', '##y'],
#  ',': [','],
#  'you': ['y', '##o', '##u'],
#  'will': ['w', '##i', '##l', '##l'],
#  'be': ['b', '##e'],
#  'able': ['a', '##b', '##l', '##e'],
#  'to': ['t', '##o'],
#  'understand': ['u',
#   '##n',
#   '##d',
#   '##e',
#   '##r',
#   '##s',
#   '##t',
#   '##a',
#   '##n',
#   '##d'],
#  'how': ['h', '##o', '##w'],
#  'they': ['t', '##h', '##e', '##y'],
#  'are': ['a', '##r', '##e'],
#  'trained': ['t', '##r', '##a', '##i', '##n', '##e', '##d'],
#  'and': ['a', '##n', '##d'],
#  'generate': ['g', '##e', '##n', '##e', '##r', '##a', '##t', '##e'],
#  'tokens': ['t', '##o', '##k', '##e', '##n', '##s']}

# %%
for word, freq in word_freqs.items():
  print(word, freq)
  split = splits[word]
  print(split)
# Out:
# This 3
# ['T', '##h', '##i', '##s']
# is 2
# ['i', '##s']
# the 1
# ['t', '##h', '##e']
# CSE 1
# ['C', '##S', '##E']
# 465 1
# ['4', '##6', '##5']
# Course 1
# ['C', '##o', '##u', '##r', '##s', '##e']
# . 4
# ['.']
# chapter 1
# ['c', '##h', '##a', '##p', '##t', '##e', '##r']
# about 1
# ['a', '##b', '##o', '##u', '##t']
# tokenization 1
# ['t', '##o', '##k', '##e', '##n', '##i', '##z', '##a', '##t', '##i', '##o', '##n']
# section 1
# ['s', '##e', '##c', '##t', '##i', '##o', '##n']
# shows 1
# ['s', '##h', '##o', '##w', '##s']
# several 1
# ['s', '##e', '##v', '##e', '##r', '##a', '##l']
# tokenizer 1
# ['t', '##o', '##k', '##e', '##n', '##i', '##z', '##e', '##r']
# algorithms 1
# ['a', '##l', '##g', '##o', '##r', '##i', '##t', '##h', '##m', '##s']
# Hopefully 1
# ['H', '##o', '##p', '##e', '##f', '##u', '##l', '##l', '##y']
# , 1
# [',']
# you 1
# ['y', '##o', '##u']
# will 1
# ['w', '##i', '##l', '##l']
# be 1
# ['b', '##e']
# able 1
# ['a', '##b', '##l', '##e']
# to 1
# ['t', '##o']
# understand 1
# ['u', '##n', '##d', '##e', '##r', '##s', '##t', '##a', '##n', '##d']
# how 1
# ['h', '##o', '##w']
# they 1
# ['t', '##h', '##e', '##y']
# are 1
# ['a', '##r', '##e']
# trained 1
# ['t', '##r', '##a', '##i', '##n', '##e', '##d']
# and 1
# ['a', '##n', '##d']
# generate 1
# ['g', '##e', '##n', '##e', '##r', '##a', '##t', '##e']
# tokens 1
# ['t', '##o', '##k', '##e', '##n', '##s']

# %%
def compute_pair_scores(splits):
    letter_freqs = defaultdict(int)
    pair_freqs = defaultdict(int)
    for word, freq in word_freqs.items():
        split = splits[word]
        if len(split) == 1:
            letter_freqs[split[0]] += freq
            continue
        for i in range(len(split) - 1):
            pair = (split[i], split[i + 1])
            letter_freqs[split[i]] += freq
            pair_freqs[pair] += freq
        letter_freqs[split[-1]] += freq

    scores = {
        pair: freq / (letter_freqs[pair[0]] * letter_freqs[pair[1]])
        for pair, freq in pair_freqs.items()
    }
    return scores

# %%
pair_scores = compute_pair_scores(splits)
for i, key in enumerate(pair_scores.keys()):
    print(f"{key}: {pair_scores[key]}")
    if i >= 5:
        break
# Out:
# ('T', '##h'): 0.125
# ('##h', '##i'): 0.0375
# ('##i', '##s'): 0.03
# ('i', '##s'): 0.1
# ('t', '##h'): 0.03571428571428571
# ('##h', '##e'): 0.0125

# %%
best_pair = ""
max_score = None
for pair, score in pair_scores.items():
    if max_score is None or max_score < score:
        best_pair = pair
        max_score = score

print(best_pair, max_score)
# Out:
# ('##S', '##E') 1.0

# %%
vocab.append("ab")

# %%
def merge_pair(a, b, splits):
    for word in word_freqs:
        split = splits[word]
        if len(split) == 1:
            continue
        i = 0
        while i < len(split) - 1:
            if split[i] == a and split[i + 1] == b:
                merge = a + b[2:] if b.startswith("##") else a + b
                split = split[:i] + [merge] + split[i + 2 :]
            else:
                i += 1
        splits[word] = split
    return splits

# %%
splits = merge_pair("a", "##b", splits)
splits["about"]
# Out:
# ['ab', '##o', '##u', '##t']

# %%
print(vocab)
# Out:
# ['[PAD]', '[UNK]', '[CLS]', '[SEP]', '[MASK]', 'T', '##h', '##i', '##s', 'i', 't', '##e', 'C', '##S', '##E', '4', '##6', '##5', '##o', '##u', '##r', '.', 'c', '##a', '##p', '##t', 'a', '##b', '##k', '##n', '##z', 's', '##c', '##w', '##v', '##l', '##g', '##m', 'H', '##f', '##y', ',', 'y', 'w', 'b', 'u', '##d', 'h', 'g', 'ab']

# %%
def encode_word(word):
    tokens = []
    while len(word) > 0:
        i = len(word)
        while i > 0 and word[:i] not in vocab:
            i -= 1
        if i == 0:
            return ["[UNK]"]
        tokens.append(word[:i])
        word = word[i:]
        if len(word) > 0:
            word = f"##{word}"
    return tokens

# %%
print(encode_word("Hugging"))
print(encode_word("445"))
# Out:
# ['H', '##u', '##g', '##g', '##i', '##n', '##g']
# ['[UNK]']

# %%
def tokenize(text):
    pre_tokenize_result = tokenizer._tokenizer.pre_tokenizer.pre_tokenize_str(text)
    pre_tokenized_text = [word for word, offset in pre_tokenize_result]
    encoded_words = [encode_word(word) for word in pre_tokenized_text]
    return sum(encoded_words, [])

# %%
tokenize("CSE 465 is the course where yoou can learn pattern recognition and neural networks!")
# Out:
# ['C',
#  '##S',
#  '##E',
#  '4',
#  '##6',
#  '##5',
#  'i',
#  '##s',
#  't',
#  '##h',
#  '##e',
#  'c',
#  '##o',
#  '##u',
#  '##r',
#  '##s',
#  '##e',
#  'w',
#  '##h',
#  '##e',
#  '##r',
#  '##e',
#  'y',
#  '##o',
#  '##o',
#  '##u',
#  'c',
#  '##a',
#  '##n',
#  '[UNK]',
#  '[UNK]',
#  '[UNK]',
#  'a',
#  '##n',
#  '##d',
#  '[UNK]',
#  '[UNK]',
#  '[UNK]']
